# %% [markdown]
# # Expérience

# %%
import os

from vote_simulation.simulation.simulation import simulation_series_from_config

print(os.getcwd())


results = simulation_series_from_config("config.toml")
# Out:
# /home/ambraser/Desktop/Stage/Code/voteSim/vote_simulation/demo/rolland-al_sim
# Running simulation series: 100%|██████████| 2/2 [00:01<00:00,  1.55it/s]
# Completed 2 simulation series.
